# %% [markdown]
# <a href="https://colab.research.google.com/github/p72/mypython/blob/master/%E6%A0%AA%E4%BE%A1%E5%8F%96%E5%BE%97.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import pandas_datareader.data as web
# %matplotlib inline

start = datetime.datetime(2005,1,1)
end   = datetime.datetime(2020,3,24)
stock = web.DataReader( ["NIKKEI225","DJIA"], "fred", start, end) 
stock.plot()

# %%
# T10YIE
bei =web.DataReader("T10YIE","fred",start,end)
bei.plot()

# %%
bei[-10:]
#スライスを使う
# Out:
#             T10YIE
# DATE
# 2020-03-11    0.96
# 2020-03-12    0.92
# 2020-03-13    0.90
# 2020-03-16    0.73
# 2020-03-17    0.63
# 2020-03-18    0.63
# 2020-03-19    0.50
# 2020-03-20    0.75
# 2020-03-23    0.80
# 2020-03-24    0.97

# %%
bei.tail(1)
# Out:
#             T10YIE
# DATE
# 2020-03-24    0.97

# %%
bei.describe()
# Out:
#             T10YIE
# count  3810.000000
# mean      2.037911
# std       0.407862
# min       0.040000
# 25%       1.792500
# 50%       2.120000
# 75%       2.340000
# max       2.760000

# %%
bei.to_csv("a.csv")
